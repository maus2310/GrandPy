# %% [markdown]
# # Differential expression
#
# One of the main applications of metabolic RNA labeling is to identify differentially expressed genes upon some perturbation [[1]](https://www.nature.com/articles/s41586-019-1369-y). The main benefit of using metabolic RNA labeling is that short-term changes can be resolved much better as compared to standard RNA-seq, since any changes of transcription that indeed happened are masked to some extent by pre-existing RNA.
#
# To perform differential analyses for data from [[2]](https://www.nature.com/articles/s41586-021-03689-8). These are SLAM-seq data from multiple time points (1h, 2h, 4h, 6h and 20h) after acute depletion of BANP. BANP is a transcriptional activator that binds to unmethylated CGCG motifs in CpG island promoters.
#
# # Loading data and QC
# We first load the grandPy package and then read the GRAND-SLAM output table directly from zenodo:

# %%
import warnings
import pandas as pd
import grandpy as gp

warnings.filterwarnings("ignore", category=UserWarning)

banp = gp.read_grand("https://zenodo.org/record/6976391/files/BANP.tsv.gz", design=("Cell", "Experimental.time", "Genotype", "duration.4sU", "has.4sU", "Replicate"))
# Out:
# Detected URL -> downloading to temp file
# Detected dense format -> using dense reader
# Temporary file BANP.tsv.gz was deleted after loading.

# %% [markdown]
# Refer to the [loading data and working with grandPy objects](notebook_03_loading_data_and_working_with_grandPy_objects.ipynb) notebook to learn more about how to load data. Note that sample metadata has been automatically extracted from the sample names via the design parameter given to `read_grand`:

# %%
banp.coldata
# Out:
#                                                   Name  Cell  \
# Name
# mESC.0h.wt.0h.no4sU.A            mESC.0h.wt.0h.no4sU.A  mESC
# mESC.0h.wt.0h.no4sU.B            mESC.0h.wt.0h.no4sU.B  mESC
# mESC.0h.wt.0h.no4sU.C            mESC.0h.wt.0h.no4sU.C  mESC
# mESC.0h.wt.2h.4sU.A                mESC.0h.wt.2h.4sU.A  mESC
# mESC.0h.wt.2h.4sU.B                mESC.0h.wt.2h.4sU.B  mESC
# mESC.0h.wt.2h.4sU.C                mESC.0h.wt.2h.4sU.C  mESC
# mESC.0h.dTag.2h.4sU.A            mESC.0h.dTag.2h.4sU.A  mESC
# mESC.0h.dTag.2h.4sU.B            mESC.0h.dTag.2h.4sU.B  mESC
# mESC.1h.dTag.30min.4sU.A      mESC.1h.dTag.30min.4sU.A  mESC
# mESC.1h.dTag.30min.4sU.B      mESC.1h.dTag.30min.4sU.B  mESC
# mESC.1h.dTag.30min.4sU.C      mESC.1h.dTag.30min.4sU.C  mESC
# mESC.2h.dTag.90min.4sU.A      mESC.2h.dTag.90min.4sU.A  mESC
# mESC.2h.dTag.90min.4sU.B      mESC.2h.dTag.90min.4sU.B  mESC
# mESC.2h.dTag.90min.4sU.C      mESC.2h.dTag.90min.4sU.C  mESC
# mESC.4h.dTag.120min.4sU.A    mESC.4h.dTag.120min.4sU.A  mESC
# mESC.4h.dTag.120min.4sU.B    mESC.4h.dTag.120min.4sU.B  mESC
# mESC.4h.dTag.120min.4sU.C    mESC.4h.dTag.120min.4sU.C  mESC
# mESC.6h.dTag.120min.4sU.A    mESC.6h.dTag.120min.4sU.A  mESC
# mESC.6h.dTag.120min.4sU.B    mESC.6h.dTag.120min.4sU.B  mESC
# mESC.6h.dTag.120min.4sU.C    mESC.6h.dTag.120min.4sU.C  mESC
# mESC.20h.dTag.120min.4sU.A  mESC.20h.dTag.120min.4sU.A  mESC
# mESC.20h.dTag.120min.4sU.B  mESC.20h.dTag.120min.4sU.B  mESC
# mESC.20h.dTag.120min.4sU.C  mESC.20h.dTag.120min.4sU.C  mESC
#
#                             Experimental.time Experimental.time.original  \
# Name
# mESC.0h.wt.0h.no4sU.A                     0.0                         0h
# mESC.0h.wt.0h.no4sU.B                     0.0                         0h
# mESC.0h.wt.0h.no4sU.C                     0.0                         0h
# mESC.0h.wt.2h.4sU.A                       0.0                         0h
# mESC.0h.wt.2h.4sU.B                       0.0                         0h
# mESC.0h.wt.2h.4sU.C                       0.0                         0h
# mESC.0h.dTag.2h.4sU.A                     0.0                         0h
# mESC.0h.dTag.2h.4sU.B                     0.0                         0h
# mESC.1h.dTag.30min.4sU.A                  1.0                         1h
# mESC.1h.dTag.30min.4sU.B                  1.0                         1h
# mESC.1h.dTag.30min.4sU.C                  1.0                         1h
# mESC.2h.dTag.90min.4sU.A                  2.0                         2h
# mESC.2h.dTag.90min.4sU.B                  2.0                         2h
# mESC.2h.dTag.90min.4sU.C                  2.0                         2h
# mESC.4h.dTag.120min.4sU.A                 4.0                         4h
# mESC.4h.dTag.120min.4sU.B                 4.0                         4h
# mESC.4h.dTag.120min.4sU.C                 4.0                         4h
# mESC.6h.dTag.120min.4sU.A                 6.0                         6h
# mESC.6h.dTag.120min.4sU.B                 6.0                         6h
# mESC.6h.dTag.120min.4sU.C                 6.0                         6h
# mESC.20h.dTag.120min.4sU.A               20.0                        20h
# mESC.20h.dTag.120min.4sU.B               20.0                        20h
# mESC.20h.dTag.120min.4sU.C               20.0                        20h
#
#                            Genotype  duration.4sU duration.4sU.original  \
# Name
# mESC.0h.wt.0h.no4sU.A            wt           0.0                    0h
# mESC.0h.wt.0h.no4sU.B            wt           0.0                    0h
# mESC.0h.wt.0h.no4sU.C            wt           0.0                    0h
# mESC.0h.wt.2h.4sU.A              wt           2.0                    2h
# mESC.0h.wt.2h.4sU.B              wt           2.0                    2h
# mESC.0h.wt.2h.4sU.C              wt           2.0                    2h
# mESC.0h.dTag.2h.4sU.A          dTag           2.0                    2h
# mESC.0h.dTag.2h.4sU.B          dTag           2.0                    2h
# mESC.1h.dTag.30min.4sU.A       dTag           0.5                 30min
# mESC.1h.dTag.30min.4sU.B       dTag           0.5                 30min
# mESC.1h.dTag.30min.4sU.C       dTag           0.5                 30min
# mESC.2h.dTag.90min.4sU.A       dTag           1.5                 90min
# mESC.2h.dTag.90min.4sU.B       dTag           1.5                 90min
# mESC.2h.dTag.90min.4sU.C       dTag           1.5                 90min
# mESC.4h.dTag.120min.4sU.A      dTag           2.0                120min
# mESC.4h.dTag.120min.4sU.B      dTag           2.0                120min
# mESC.4h.dTag.120min.4sU.C      dTag           2.0                120min
# mESC.6h.dTag.120min.4sU.A      dTag           2.0                120min
# mESC.6h.dTag.120min.4sU.B      dTag           2.0                120min
# mESC.6h.dTag.120min.4sU.C      dTag           2.0                120min
# mESC.20h.dTag.120min.4sU.A     dTag           2.0                120min
# mESC.20h.dTag.120min.4sU.B     dTag           2.0                120min
# mESC.20h.dTag.120min.4sU.C     dTag           2.0                120min
#
#                            has.4sU Replicate  no4sU Condition
# Name
# mESC.0h.wt.0h.no4sU.A        no4sU         A   True   Control
# mESC.0h.wt.0h.no4sU.B        no4sU         B   True   Control
# mESC.0h.wt.0h.no4sU.C        no4sU         C   True   Control
# mESC.0h.wt.2h.4sU.A            4sU         A  False   Control
# mESC.0h.wt.2h.4sU.B            4sU         B  False   Control
# mESC.0h.wt.2h.4sU.C            4sU         C  False   Control
# mESC.0h.dTag.2h.4sU.A          4sU         A  False   Control
# mESC.0h.dTag.2h.4sU.B          4sU         B  False   Control
# mESC.1h.dTag.30min.4sU.A       4sU         A  False   Control
# mESC.1h.dTag.30min.4sU.B       4sU         B  False   Control
# mESC.1h.dTag.30min.4sU.C       4sU         C  False   Control
# mESC.2h.dTag.90min.4sU.A       4sU         A  False   Control
# mESC.2h.dTag.90min.4sU.B       4sU         B  False   Control
# mESC.2h.dTag.90min.4sU.C       4sU         C  False   Control
# mESC.4h.dTag.120min.4sU.A      4sU         A  False   Control
# mESC.4h.dTag.120min.4sU.B      4sU         B  False   Control
# mESC.4h.dTag.120min.4sU.C      4sU         C  False   Control
# mESC.6h.dTag.120min.4sU.A      4sU         A  False   Control
# mESC.6h.dTag.120min.4sU.B      4sU         B  False   Control
# mESC.6h.dTag.120min.4sU.C      4sU         C  False   Control
# mESC.20h.dTag.120min.4sU.A     4sU         A  False   Control
# mESC.20h.dTag.120min.4sU.B     4sU         B  False   Control
# mESC.20h.dTag.120min.4sU.C     4sU         C  False   Control

# %% [markdown]
# The experimental time column indicates the period of time the sample was treated with the dTAG13 compound that induces acute depletion of BANP within 30 minutes.
#
# By default GRAND-SLAM will report data on all genes (with at least one mapped read), and `read_grand` will read all these genes from the output:

# %%
print(banp)
# Out:
# GrandPy:
# Read from BANP.tsv
# 24616 genes, 23 samples/cells
# Available data slots: ['ntr', 'alpha', 'beta', 'count']
# Available analyses: []
# Available plots: {}
# Default data slot: count

# %% [markdown]
# Thus, we filter to only include genes that have at least 100 reads in at least 11 samples:

# %%
banp = banp.filter_genes(min_expression=100, min_columns=11)
print(banp)
# Out:
# GrandPy:
# Read from BANP.tsv
# 11147 genes, 23 samples/cells
# Available data slots: ['ntr', 'alpha', 'beta', 'count']
# Available analyses: []
# Available plots: {}
# Default data slot: count

# %% [markdown]
# The actual data is available in 'slots'. `read_grand` adds the read counts, new to toal RNA ratios (NTRs) and information on the NTR posterior distribution (alpha, beta).
#
# As a quick quality check, we can inspect a principal component analysis of all samples involved:

# %%
gp.plot_pca(banp)
# Out:
# Fitting dispersions...
# ... done in 0.01 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.01 seconds.
#
# Fitting LFCs...
# ... done in 0.01 seconds.

# %% [markdown]
# By default, the samples are colored according to the `Condition`. `Condition` has a special meaning in grandPy, not only for `PlotPCA`, but also for other analyses (see below). We do not have a specific condition set, so the default ('Control') was used. (see the Coldata above) There are two ways how the condition can be set:
#
# 1. Use the keyword "Condition" in the design parameter to `read_grand`. Use this, if you have a useful condition as part of your sample names.
# 2. Call the `with_condition` method.
#
# Here a useful condition is to combine the genotype, timepoint and 4sU status. We can set this like this (for more information, see the [Loading data vignette](notebook_03_loading_data_and_working_with_grandPy_objects.ipynb)):

# %%
banp = banp.with_condition(["Genotype", "Experimental.time.original", "has.4sU"])
banp.coldata
# Out:
#                                                   Name  Cell  \
# Name
# mESC.0h.wt.0h.no4sU.A            mESC.0h.wt.0h.no4sU.A  mESC
# mESC.0h.wt.0h.no4sU.B            mESC.0h.wt.0h.no4sU.B  mESC
# mESC.0h.wt.0h.no4sU.C            mESC.0h.wt.0h.no4sU.C  mESC
# mESC.0h.wt.2h.4sU.A                mESC.0h.wt.2h.4sU.A  mESC
# mESC.0h.wt.2h.4sU.B                mESC.0h.wt.2h.4sU.B  mESC
# mESC.0h.wt.2h.4sU.C                mESC.0h.wt.2h.4sU.C  mESC
# mESC.0h.dTag.2h.4sU.A            mESC.0h.dTag.2h.4sU.A  mESC
# mESC.0h.dTag.2h.4sU.B            mESC.0h.dTag.2h.4sU.B  mESC
# mESC.1h.dTag.30min.4sU.A      mESC.1h.dTag.30min.4sU.A  mESC
# mESC.1h.dTag.30min.4sU.B      mESC.1h.dTag.30min.4sU.B  mESC
# mESC.1h.dTag.30min.4sU.C      mESC.1h.dTag.30min.4sU.C  mESC
# mESC.2h.dTag.90min.4sU.A      mESC.2h.dTag.90min.4sU.A  mESC
# mESC.2h.dTag.90min.4sU.B      mESC.2h.dTag.90min.4sU.B  mESC
# mESC.2h.dTag.90min.4sU.C      mESC.2h.dTag.90min.4sU.C  mESC
# mESC.4h.dTag.120min.4sU.A    mESC.4h.dTag.120min.4sU.A  mESC
# mESC.4h.dTag.120min.4sU.B    mESC.4h.dTag.120min.4sU.B  mESC
# mESC.4h.dTag.120min.4sU.C    mESC.4h.dTag.120min.4sU.C  mESC
# mESC.6h.dTag.120min.4sU.A    mESC.6h.dTag.120min.4sU.A  mESC
# mESC.6h.dTag.120min.4sU.B    mESC.6h.dTag.120min.4sU.B  mESC
# mESC.6h.dTag.120min.4sU.C    mESC.6h.dTag.120min.4sU.C  mESC
# mESC.20h.dTag.120min.4sU.A  mESC.20h.dTag.120min.4sU.A  mESC
# mESC.20h.dTag.120min.4sU.B  mESC.20h.dTag.120min.4sU.B  mESC
# mESC.20h.dTag.120min.4sU.C  mESC.20h.dTag.120min.4sU.C  mESC
#
#                             Experimental.time Experimental.time.original  \
# Name
# mESC.0h.wt.0h.no4sU.A                     0.0                         0h
# mESC.0h.wt.0h.no4sU.B                     0.0                         0h
# mESC.0h.wt.0h.no4sU.C                     0.0                         0h
# mESC.0h.wt.2h.4sU.A                       0.0                         0h
# mESC.0h.wt.2h.4sU.B                       0.0                         0h
# mESC.0h.wt.2h.4sU.C                       0.0                         0h
# mESC.0h.dTag.2h.4sU.A                     0.0                         0h
# mESC.0h.dTag.2h.4sU.B                     0.0                         0h
# mESC.1h.dTag.30min.4sU.A                  1.0                         1h
# mESC.1h.dTag.30min.4sU.B                  1.0                         1h
# mESC.1h.dTag.30min.4sU.C                  1.0                         1h
# mESC.2h.dTag.90min.4sU.A                  2.0                         2h
# mESC.2h.dTag.90min.4sU.B                  2.0                         2h
# mESC.2h.dTag.90min.4sU.C                  2.0                         2h
# mESC.4h.dTag.120min.4sU.A                 4.0                         4h
# mESC.4h.dTag.120min.4sU.B                 4.0                         4h
# mESC.4h.dTag.120min.4sU.C                 4.0                         4h
# mESC.6h.dTag.120min.4sU.A                 6.0                         6h
# mESC.6h.dTag.120min.4sU.B                 6.0                         6h
# mESC.6h.dTag.120min.4sU.C                 6.0                         6h
# mESC.20h.dTag.120min.4sU.A               20.0                        20h
# mESC.20h.dTag.120min.4sU.B               20.0                        20h
# mESC.20h.dTag.120min.4sU.C               20.0                        20h
#
#                            Genotype  duration.4sU duration.4sU.original  \
# Name
# mESC.0h.wt.0h.no4sU.A            wt           0.0                    0h
# mESC.0h.wt.0h.no4sU.B            wt           0.0                    0h
# mESC.0h.wt.0h.no4sU.C            wt           0.0                    0h
# mESC.0h.wt.2h.4sU.A              wt           2.0                    2h
# mESC.0h.wt.2h.4sU.B              wt           2.0                    2h
# mESC.0h.wt.2h.4sU.C              wt           2.0                    2h
# mESC.0h.dTag.2h.4sU.A          dTag           2.0                    2h
# mESC.0h.dTag.2h.4sU.B          dTag           2.0                    2h
# mESC.1h.dTag.30min.4sU.A       dTag           0.5                 30min
# mESC.1h.dTag.30min.4sU.B       dTag           0.5                 30min
# mESC.1h.dTag.30min.4sU.C       dTag           0.5                 30min
# mESC.2h.dTag.90min.4sU.A       dTag           1.5                 90min
# mESC.2h.dTag.90min.4sU.B       dTag           1.5                 90min
# mESC.2h.dTag.90min.4sU.C       dTag           1.5                 90min
# mESC.4h.dTag.120min.4sU.A      dTag           2.0                120min
# mESC.4h.dTag.120min.4sU.B      dTag           2.0                120min
# mESC.4h.dTag.120min.4sU.C      dTag           2.0                120min
# mESC.6h.dTag.120min.4sU.A      dTag           2.0                120min
# mESC.6h.dTag.120min.4sU.B      dTag           2.0                120min
# mESC.6h.dTag.120min.4sU.C      dTag           2.0                120min
# mESC.20h.dTag.120min.4sU.A     dTag           2.0                120min
# mESC.20h.dTag.120min.4sU.B     dTag           2.0                120min
# mESC.20h.dTag.120min.4sU.C     dTag           2.0                120min
#
#                            has.4sU Replicate  no4sU     Condition
# Name
# mESC.0h.wt.0h.no4sU.A        no4sU         A   True   wt 0h no4sU
# mESC.0h.wt.0h.no4sU.B        no4sU         B   True   wt 0h no4sU
# mESC.0h.wt.0h.no4sU.C        no4sU         C   True   wt 0h no4sU
# mESC.0h.wt.2h.4sU.A            4sU         A  False     wt 0h 4sU
# mESC.0h.wt.2h.4sU.B            4sU         B  False     wt 0h 4sU
# mESC.0h.wt.2h.4sU.C            4sU         C  False     wt 0h 4sU
# mESC.0h.dTag.2h.4sU.A          4sU         A  False   dTag 0h 4sU
# mESC.0h.dTag.2h.4sU.B          4sU         B  False   dTag 0h 4sU
# mESC.1h.dTag.30min.4sU.A       4sU         A  False   dTag 1h 4sU
# mESC.1h.dTag.30min.4sU.B       4sU         B  False   dTag 1h 4sU
# mESC.1h.dTag.30min.4sU.C       4sU         C  False   dTag 1h 4sU
# mESC.2h.dTag.90min.4sU.A       4sU         A  False   dTag 2h 4sU
# mESC.2h.dTag.90min.4sU.B       4sU         B  False   dTag 2h 4sU
# mESC.2h.dTag.90min.4sU.C       4sU         C  False   dTag 2h 4sU
# mESC.4h.dTag.120min.4sU.A      4sU         A  False   dTag 4h 4sU
# mESC.4h.dTag.120min.4sU.B      4sU         B  False   dTag 4h 4sU
# mESC.4h.dTag.120min.4sU.C      4sU         C  False   dTag 4h 4sU
# mESC.6h.dTag.120min.4sU.A      4sU         A  False   dTag 6h 4sU
# mESC.6h.dTag.120min.4sU.B      4sU         B  False   dTag 6h 4sU
# mESC.6h.dTag.120min.4sU.C      4sU         C  False   dTag 6h 4sU
# mESC.20h.dTag.120min.4sU.A     4sU         A  False  dTag 20h 4sU
# mESC.20h.dTag.120min.4sU.B     4sU         B  False  dTag 20h 4sU
# mESC.20h.dTag.120min.4sU.C     4sU         C  False  dTag 20h 4sU

# %%
gp.plot_pca(banp)

# %% [markdown]
# We see that 4sU treatment affected total RNA levels (there is a clear difference between no4sU and 4sU for wt). Inserting the degron tag also had an effect (there is a clear difference between wt and dTag.0h, the latter is a sample treated with 4sU for 2h, but was not treated with dTAG13).
#
# Before we can investigate these effects, we need to learn how to perform pairwise differential expression analysis in GrandPy. Such pairwise analyses are based on 'contrast matrices', which can conveniently be constructed by using the `get_contrasts` method:

# %%
banp.get_contrasts()

# %% [markdown]
# Each column of the contrast matrix defines a single pairwise comparison: Samples with 0 are left out, and samples with 1 are compared vs samples with -1 (e.g. if log2 fold change are computed, comparing A vs B means log2(A/B)).
#
# Without specifying any parameters, GetContrasts will discard no4sU samples, and all pairwise comparisons of the remaining conditions (here there are 7 conditions having 4sU, i.e. 21 pairwise comparisons) are generated. This behavior can be changed by the contrasts parameter.
#
# This parameter is a list of length 1, 2 or 3. The first element always is a name of a column in the Coldata table, the second and third (if given) need to be values of this column. If only the column is given, all pairwise comparisons are generated (i.e. this is the default behavior shown above, for columns “Condition”):

# %%
banp.get_contrasts(contrast = "Condition")
# Out:
#                             wt 0h no4sU vs wt 0h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                            1.0
# mESC.0h.wt.0h.no4sU.B                            1.0
# mESC.0h.wt.0h.no4sU.C                            1.0
# mESC.0h.wt.2h.4sU.A                             -1.0
# mESC.0h.wt.2h.4sU.B                             -1.0
# mESC.0h.wt.2h.4sU.C                             -1.0
# mESC.0h.dTag.2h.4sU.A                            0.0
# mESC.0h.dTag.2h.4sU.B                            0.0
# mESC.1h.dTag.30min.4sU.A                         0.0
# mESC.1h.dTag.30min.4sU.B                         0.0
# mESC.1h.dTag.30min.4sU.C                         0.0
# mESC.2h.dTag.90min.4sU.A                         0.0
# mESC.2h.dTag.90min.4sU.B                         0.0
# mESC.2h.dTag.90min.4sU.C                         0.0
# mESC.4h.dTag.120min.4sU.A                        0.0
# mESC.4h.dTag.120min.4sU.B                        0.0
# mESC.4h.dTag.120min.4sU.C                        0.0
# mESC.6h.dTag.120min.4sU.A                        0.0
# mESC.6h.dTag.120min.4sU.B                        0.0
# mESC.6h.dTag.120min.4sU.C                        0.0
# mESC.20h.dTag.120min.4sU.A                       0.0
# mESC.20h.dTag.120min.4sU.B                       0.0
# mESC.20h.dTag.120min.4sU.C                       0.0
#
#                             wt 0h no4sU vs dTag 0h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              1.0
# mESC.0h.wt.0h.no4sU.B                              1.0
# mESC.0h.wt.0h.no4sU.C                              1.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                             -1.0
# mESC.0h.dTag.2h.4sU.B                             -1.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             wt 0h no4sU vs dTag 1h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              1.0
# mESC.0h.wt.0h.no4sU.B                              1.0
# mESC.0h.wt.0h.no4sU.C                              1.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                          -1.0
# mESC.1h.dTag.30min.4sU.B                          -1.0
# mESC.1h.dTag.30min.4sU.C                          -1.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             wt 0h no4sU vs dTag 2h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              1.0
# mESC.0h.wt.0h.no4sU.B                              1.0
# mESC.0h.wt.0h.no4sU.C                              1.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                          -1.0
# mESC.2h.dTag.90min.4sU.B                          -1.0
# mESC.2h.dTag.90min.4sU.C                          -1.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             wt 0h no4sU vs dTag 4h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              1.0
# mESC.0h.wt.0h.no4sU.B                              1.0
# mESC.0h.wt.0h.no4sU.C                              1.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                         -1.0
# mESC.4h.dTag.120min.4sU.B                         -1.0
# mESC.4h.dTag.120min.4sU.C                         -1.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             wt 0h no4sU vs dTag 6h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              1.0
# mESC.0h.wt.0h.no4sU.B                              1.0
# mESC.0h.wt.0h.no4sU.C                              1.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                         -1.0
# mESC.6h.dTag.120min.4sU.B                         -1.0
# mESC.6h.dTag.120min.4sU.C                         -1.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             wt 0h no4sU vs dTag 20h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                               1.0
# mESC.0h.wt.0h.no4sU.B                               1.0
# mESC.0h.wt.0h.no4sU.C                               1.0
# mESC.0h.wt.2h.4sU.A                                 0.0
# mESC.0h.wt.2h.4sU.B                                 0.0
# mESC.0h.wt.2h.4sU.C                                 0.0
# mESC.0h.dTag.2h.4sU.A                               0.0
# mESC.0h.dTag.2h.4sU.B                               0.0
# mESC.1h.dTag.30min.4sU.A                            0.0
# mESC.1h.dTag.30min.4sU.B                            0.0
# mESC.1h.dTag.30min.4sU.C                            0.0
# mESC.2h.dTag.90min.4sU.A                            0.0
# mESC.2h.dTag.90min.4sU.B                            0.0
# mESC.2h.dTag.90min.4sU.C                            0.0
# mESC.4h.dTag.120min.4sU.A                           0.0
# mESC.4h.dTag.120min.4sU.B                           0.0
# mESC.4h.dTag.120min.4sU.C                           0.0
# mESC.6h.dTag.120min.4sU.A                           0.0
# mESC.6h.dTag.120min.4sU.B                           0.0
# mESC.6h.dTag.120min.4sU.C                           0.0
# mESC.20h.dTag.120min.4sU.A                         -1.0
# mESC.20h.dTag.120min.4sU.B                         -1.0
# mESC.20h.dTag.120min.4sU.C                         -1.0
#
#                             wt 0h 4sU vs dTag 0h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                            0.0
# mESC.0h.wt.0h.no4sU.B                            0.0
# mESC.0h.wt.0h.no4sU.C                            0.0
# mESC.0h.wt.2h.4sU.A                              1.0
# mESC.0h.wt.2h.4sU.B                              1.0
# mESC.0h.wt.2h.4sU.C                              1.0
# mESC.0h.dTag.2h.4sU.A                           -1.0
# mESC.0h.dTag.2h.4sU.B                           -1.0
# mESC.1h.dTag.30min.4sU.A                         0.0
# mESC.1h.dTag.30min.4sU.B                         0.0
# mESC.1h.dTag.30min.4sU.C                         0.0
# mESC.2h.dTag.90min.4sU.A                         0.0
# mESC.2h.dTag.90min.4sU.B                         0.0
# mESC.2h.dTag.90min.4sU.C                         0.0
# mESC.4h.dTag.120min.4sU.A                        0.0
# mESC.4h.dTag.120min.4sU.B                        0.0
# mESC.4h.dTag.120min.4sU.C                        0.0
# mESC.6h.dTag.120min.4sU.A                        0.0
# mESC.6h.dTag.120min.4sU.B                        0.0
# mESC.6h.dTag.120min.4sU.C                        0.0
# mESC.20h.dTag.120min.4sU.A                       0.0
# mESC.20h.dTag.120min.4sU.B                       0.0
# mESC.20h.dTag.120min.4sU.C                       0.0
#
#                             wt 0h 4sU vs dTag 1h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                            0.0
# mESC.0h.wt.0h.no4sU.B                            0.0
# mESC.0h.wt.0h.no4sU.C                            0.0
# mESC.0h.wt.2h.4sU.A                              1.0
# mESC.0h.wt.2h.4sU.B                              1.0
# mESC.0h.wt.2h.4sU.C                              1.0
# mESC.0h.dTag.2h.4sU.A                            0.0
# mESC.0h.dTag.2h.4sU.B                            0.0
# mESC.1h.dTag.30min.4sU.A                        -1.0
# mESC.1h.dTag.30min.4sU.B                        -1.0
# mESC.1h.dTag.30min.4sU.C                        -1.0
# mESC.2h.dTag.90min.4sU.A                         0.0
# mESC.2h.dTag.90min.4sU.B                         0.0
# mESC.2h.dTag.90min.4sU.C                         0.0
# mESC.4h.dTag.120min.4sU.A                        0.0
# mESC.4h.dTag.120min.4sU.B                        0.0
# mESC.4h.dTag.120min.4sU.C                        0.0
# mESC.6h.dTag.120min.4sU.A                        0.0
# mESC.6h.dTag.120min.4sU.B                        0.0
# mESC.6h.dTag.120min.4sU.C                        0.0
# mESC.20h.dTag.120min.4sU.A                       0.0
# mESC.20h.dTag.120min.4sU.B                       0.0
# mESC.20h.dTag.120min.4sU.C                       0.0
#
#                             wt 0h 4sU vs dTag 2h 4sU  ...  \
# Name                                                  ...
# mESC.0h.wt.0h.no4sU.A                            0.0  ...
# mESC.0h.wt.0h.no4sU.B                            0.0  ...
# mESC.0h.wt.0h.no4sU.C                            0.0  ...
# mESC.0h.wt.2h.4sU.A                              1.0  ...
# mESC.0h.wt.2h.4sU.B                              1.0  ...
# mESC.0h.wt.2h.4sU.C                              1.0  ...
# mESC.0h.dTag.2h.4sU.A                            0.0  ...
# mESC.0h.dTag.2h.4sU.B                            0.0  ...
# mESC.1h.dTag.30min.4sU.A                         0.0  ...
# mESC.1h.dTag.30min.4sU.B                         0.0  ...
# mESC.1h.dTag.30min.4sU.C                         0.0  ...
# mESC.2h.dTag.90min.4sU.A                        -1.0  ...
# mESC.2h.dTag.90min.4sU.B                        -1.0  ...
# mESC.2h.dTag.90min.4sU.C                        -1.0  ...
# mESC.4h.dTag.120min.4sU.A                        0.0  ...
# mESC.4h.dTag.120min.4sU.B                        0.0  ...
# mESC.4h.dTag.120min.4sU.C                        0.0  ...
# mESC.6h.dTag.120min.4sU.A                        0.0  ...
# mESC.6h.dTag.120min.4sU.B                        0.0  ...
# mESC.6h.dTag.120min.4sU.C                        0.0  ...
# mESC.20h.dTag.120min.4sU.A                       0.0  ...
# mESC.20h.dTag.120min.4sU.B                       0.0  ...
# mESC.20h.dTag.120min.4sU.C                       0.0  ...
#
#                             dTag 1h 4sU vs dTag 2h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                           1.0
# mESC.1h.dTag.30min.4sU.B                           1.0
# mESC.1h.dTag.30min.4sU.C                           1.0
# mESC.2h.dTag.90min.4sU.A                          -1.0
# mESC.2h.dTag.90min.4sU.B                          -1.0
# mESC.2h.dTag.90min.4sU.C                          -1.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 1h 4sU vs dTag 4h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                           1.0
# mESC.1h.dTag.30min.4sU.B                           1.0
# mESC.1h.dTag.30min.4sU.C                           1.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                         -1.0
# mESC.4h.dTag.120min.4sU.B                         -1.0
# mESC.4h.dTag.120min.4sU.C                         -1.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 1h 4sU vs dTag 6h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                           1.0
# mESC.1h.dTag.30min.4sU.B                           1.0
# mESC.1h.dTag.30min.4sU.C                           1.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                         -1.0
# mESC.6h.dTag.120min.4sU.B                         -1.0
# mESC.6h.dTag.120min.4sU.C                         -1.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 1h 4sU vs dTag 20h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                               0.0
# mESC.0h.wt.0h.no4sU.B                               0.0
# mESC.0h.wt.0h.no4sU.C                               0.0
# mESC.0h.wt.2h.4sU.A                                 0.0
# mESC.0h.wt.2h.4sU.B                                 0.0
# mESC.0h.wt.2h.4sU.C                                 0.0
# mESC.0h.dTag.2h.4sU.A                               0.0
# mESC.0h.dTag.2h.4sU.B                               0.0
# mESC.1h.dTag.30min.4sU.A                            1.0
# mESC.1h.dTag.30min.4sU.B                            1.0
# mESC.1h.dTag.30min.4sU.C                            1.0
# mESC.2h.dTag.90min.4sU.A                            0.0
# mESC.2h.dTag.90min.4sU.B                            0.0
# mESC.2h.dTag.90min.4sU.C                            0.0
# mESC.4h.dTag.120min.4sU.A                           0.0
# mESC.4h.dTag.120min.4sU.B                           0.0
# mESC.4h.dTag.120min.4sU.C                           0.0
# mESC.6h.dTag.120min.4sU.A                           0.0
# mESC.6h.dTag.120min.4sU.B                           0.0
# mESC.6h.dTag.120min.4sU.C                           0.0
# mESC.20h.dTag.120min.4sU.A                         -1.0
# mESC.20h.dTag.120min.4sU.B                         -1.0
# mESC.20h.dTag.120min.4sU.C                         -1.0
#
#                             dTag 2h 4sU vs dTag 4h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           1.0
# mESC.2h.dTag.90min.4sU.B                           1.0
# mESC.2h.dTag.90min.4sU.C                           1.0
# mESC.4h.dTag.120min.4sU.A                         -1.0
# mESC.4h.dTag.120min.4sU.B                         -1.0
# mESC.4h.dTag.120min.4sU.C                         -1.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 2h 4sU vs dTag 6h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           1.0
# mESC.2h.dTag.90min.4sU.B                           1.0
# mESC.2h.dTag.90min.4sU.C                           1.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                         -1.0
# mESC.6h.dTag.120min.4sU.B                         -1.0
# mESC.6h.dTag.120min.4sU.C                         -1.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 2h 4sU vs dTag 20h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                               0.0
# mESC.0h.wt.0h.no4sU.B                               0.0
# mESC.0h.wt.0h.no4sU.C                               0.0
# mESC.0h.wt.2h.4sU.A                                 0.0
# mESC.0h.wt.2h.4sU.B                                 0.0
# mESC.0h.wt.2h.4sU.C                                 0.0
# mESC.0h.dTag.2h.4sU.A                               0.0
# mESC.0h.dTag.2h.4sU.B                               0.0
# mESC.1h.dTag.30min.4sU.A                            0.0
# mESC.1h.dTag.30min.4sU.B                            0.0
# mESC.1h.dTag.30min.4sU.C                            0.0
# mESC.2h.dTag.90min.4sU.A                            1.0
# mESC.2h.dTag.90min.4sU.B                            1.0
# mESC.2h.dTag.90min.4sU.C                            1.0
# mESC.4h.dTag.120min.4sU.A                           0.0
# mESC.4h.dTag.120min.4sU.B                           0.0
# mESC.4h.dTag.120min.4sU.C                           0.0
# mESC.6h.dTag.120min.4sU.A                           0.0
# mESC.6h.dTag.120min.4sU.B                           0.0
# mESC.6h.dTag.120min.4sU.C                           0.0
# mESC.20h.dTag.120min.4sU.A                         -1.0
# mESC.20h.dTag.120min.4sU.B                         -1.0
# mESC.20h.dTag.120min.4sU.C                         -1.0
#
#                             dTag 4h 4sU vs dTag 6h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                              0.0
# mESC.0h.dTag.2h.4sU.B                              0.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                          1.0
# mESC.4h.dTag.120min.4sU.B                          1.0
# mESC.4h.dTag.120min.4sU.C                          1.0
# mESC.6h.dTag.120min.4sU.A                         -1.0
# mESC.6h.dTag.120min.4sU.B                         -1.0
# mESC.6h.dTag.120min.4sU.C                         -1.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 4h 4sU vs dTag 20h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                               0.0
# mESC.0h.wt.0h.no4sU.B                               0.0
# mESC.0h.wt.0h.no4sU.C                               0.0
# mESC.0h.wt.2h.4sU.A                                 0.0
# mESC.0h.wt.2h.4sU.B                                 0.0
# mESC.0h.wt.2h.4sU.C                                 0.0
# mESC.0h.dTag.2h.4sU.A                               0.0
# mESC.0h.dTag.2h.4sU.B                               0.0
# mESC.1h.dTag.30min.4sU.A                            0.0
# mESC.1h.dTag.30min.4sU.B                            0.0
# mESC.1h.dTag.30min.4sU.C                            0.0
# mESC.2h.dTag.90min.4sU.A                            0.0
# mESC.2h.dTag.90min.4sU.B                            0.0
# mESC.2h.dTag.90min.4sU.C                            0.0
# mESC.4h.dTag.120min.4sU.A                           1.0
# mESC.4h.dTag.120min.4sU.B                           1.0
# mESC.4h.dTag.120min.4sU.C                           1.0
# mESC.6h.dTag.120min.4sU.A                           0.0
# mESC.6h.dTag.120min.4sU.B                           0.0
# mESC.6h.dTag.120min.4sU.C                           0.0
# mESC.20h.dTag.120min.4sU.A                         -1.0
# mESC.20h.dTag.120min.4sU.B                         -1.0
# mESC.20h.dTag.120min.4sU.C                         -1.0
#
#                             dTag 6h 4sU vs dTag 20h 4sU
# Name
# mESC.0h.wt.0h.no4sU.A                               0.0
# mESC.0h.wt.0h.no4sU.B                               0.0
# mESC.0h.wt.0h.no4sU.C                               0.0
# mESC.0h.wt.2h.4sU.A                                 0.0
# mESC.0h.wt.2h.4sU.B                                 0.0
# mESC.0h.wt.2h.4sU.C                                 0.0
# mESC.0h.dTag.2h.4sU.A                               0.0
# mESC.0h.dTag.2h.4sU.B                               0.0
# mESC.1h.dTag.30min.4sU.A                            0.0
# mESC.1h.dTag.30min.4sU.B                            0.0
# mESC.1h.dTag.30min.4sU.C                            0.0
# mESC.2h.dTag.90min.4sU.A                            0.0
# mESC.2h.dTag.90min.4sU.B                            0.0
# mESC.2h.dTag.90min.4sU.C                            0.0
# mESC.4h.dTag.120min.4sU.A                           0.0
# mESC.4h.dTag.120min.4sU.B                           0.0
# mESC.4h.dTag.120min.4sU.C                           0.0
# mESC.6h.dTag.120min.4sU.A                           1.0
# mESC.6h.dTag.120min.4sU.B                           1.0
# mESC.6h.dTag.120min.4sU.C                           1.0
# mESC.20h.dTag.120min.4sU.A                         -1.0
# mESC.20h.dTag.120min.4sU.B                         -1.0
# mESC.20h.dTag.120min.4sU.C                         -1.0
#
# [23 rows x 28 columns]

# %% [markdown]
# If one value is given, all pairwise comparisons with this as reference are created (i.e., if A is given, all X vs A for all other values X):

# %%
banp.get_contrasts(contrast = ["Condition", "dTag 0h 4sU"])
# Out:
#                             wt 0h no4sU vs dTag 0h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              1.0
# mESC.0h.wt.0h.no4sU.B                              1.0
# mESC.0h.wt.0h.no4sU.C                              1.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                             -1.0
# mESC.0h.dTag.2h.4sU.B                             -1.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             wt 0h 4sU vs dTag 0h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                            0.0
# mESC.0h.wt.0h.no4sU.B                            0.0
# mESC.0h.wt.0h.no4sU.C                            0.0
# mESC.0h.wt.2h.4sU.A                              1.0
# mESC.0h.wt.2h.4sU.B                              1.0
# mESC.0h.wt.2h.4sU.C                              1.0
# mESC.0h.dTag.2h.4sU.A                           -1.0
# mESC.0h.dTag.2h.4sU.B                           -1.0
# mESC.1h.dTag.30min.4sU.A                         0.0
# mESC.1h.dTag.30min.4sU.B                         0.0
# mESC.1h.dTag.30min.4sU.C                         0.0
# mESC.2h.dTag.90min.4sU.A                         0.0
# mESC.2h.dTag.90min.4sU.B                         0.0
# mESC.2h.dTag.90min.4sU.C                         0.0
# mESC.4h.dTag.120min.4sU.A                        0.0
# mESC.4h.dTag.120min.4sU.B                        0.0
# mESC.4h.dTag.120min.4sU.C                        0.0
# mESC.6h.dTag.120min.4sU.A                        0.0
# mESC.6h.dTag.120min.4sU.B                        0.0
# mESC.6h.dTag.120min.4sU.C                        0.0
# mESC.20h.dTag.120min.4sU.A                       0.0
# mESC.20h.dTag.120min.4sU.B                       0.0
# mESC.20h.dTag.120min.4sU.C                       0.0
#
#                             dTag 1h 4sU vs dTag 0h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                             -1.0
# mESC.0h.dTag.2h.4sU.B                             -1.0
# mESC.1h.dTag.30min.4sU.A                           1.0
# mESC.1h.dTag.30min.4sU.B                           1.0
# mESC.1h.dTag.30min.4sU.C                           1.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 2h 4sU vs dTag 0h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                             -1.0
# mESC.0h.dTag.2h.4sU.B                             -1.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           1.0
# mESC.2h.dTag.90min.4sU.B                           1.0
# mESC.2h.dTag.90min.4sU.C                           1.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 4h 4sU vs dTag 0h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                             -1.0
# mESC.0h.dTag.2h.4sU.B                             -1.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                          1.0
# mESC.4h.dTag.120min.4sU.B                          1.0
# mESC.4h.dTag.120min.4sU.C                          1.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 6h 4sU vs dTag 0h 4sU  \
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                             -1.0
# mESC.0h.dTag.2h.4sU.B                             -1.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           0.0
# mESC.2h.dTag.90min.4sU.B                           0.0
# mESC.2h.dTag.90min.4sU.C                           0.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                          1.0
# mESC.6h.dTag.120min.4sU.B                          1.0
# mESC.6h.dTag.120min.4sU.C                          1.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0
#
#                             dTag 20h 4sU vs dTag 0h 4sU
# Name
# mESC.0h.wt.0h.no4sU.A                               0.0
# mESC.0h.wt.0h.no4sU.B                               0.0
# mESC.0h.wt.0h.no4sU.C                               0.0
# mESC.0h.wt.2h.4sU.A                                 0.0
# mESC.0h.wt.2h.4sU.B                                 0.0
# mESC.0h.wt.2h.4sU.C                                 0.0
# mESC.0h.dTag.2h.4sU.A                              -1.0
# mESC.0h.dTag.2h.4sU.B                              -1.0
# mESC.1h.dTag.30min.4sU.A                            0.0
# mESC.1h.dTag.30min.4sU.B                            0.0
# mESC.1h.dTag.30min.4sU.C                            0.0
# mESC.2h.dTag.90min.4sU.A                            0.0
# mESC.2h.dTag.90min.4sU.B                            0.0
# mESC.2h.dTag.90min.4sU.C                            0.0
# mESC.4h.dTag.120min.4sU.A                           0.0
# mESC.4h.dTag.120min.4sU.B                           0.0
# mESC.4h.dTag.120min.4sU.C                           0.0
# mESC.6h.dTag.120min.4sU.A                           0.0
# mESC.6h.dTag.120min.4sU.B                           0.0
# mESC.6h.dTag.120min.4sU.C                           0.0
# mESC.20h.dTag.120min.4sU.A                          1.0
# mESC.20h.dTag.120min.4sU.B                          1.0
# mESC.20h.dTag.120min.4sU.C                          1.0

# %% [markdown]
# If two values are given, a single pairwise comparison is created:

# %%
banp.get_contrasts(contrast = ["Condition", "dTag 2h 4sU", "dTag 0h 4sU"])
# Out:
#                             dTag 2h 4sU vs dTag 0h 4sU
# Name
# mESC.0h.wt.0h.no4sU.A                              0.0
# mESC.0h.wt.0h.no4sU.B                              0.0
# mESC.0h.wt.0h.no4sU.C                              0.0
# mESC.0h.wt.2h.4sU.A                                0.0
# mESC.0h.wt.2h.4sU.B                                0.0
# mESC.0h.wt.2h.4sU.C                                0.0
# mESC.0h.dTag.2h.4sU.A                             -1.0
# mESC.0h.dTag.2h.4sU.B                             -1.0
# mESC.1h.dTag.30min.4sU.A                           0.0
# mESC.1h.dTag.30min.4sU.B                           0.0
# mESC.1h.dTag.30min.4sU.C                           0.0
# mESC.2h.dTag.90min.4sU.A                           1.0
# mESC.2h.dTag.90min.4sU.B                           1.0
# mESC.2h.dTag.90min.4sU.C                           1.0
# mESC.4h.dTag.120min.4sU.A                          0.0
# mESC.4h.dTag.120min.4sU.B                          0.0
# mESC.4h.dTag.120min.4sU.C                          0.0
# mESC.6h.dTag.120min.4sU.A                          0.0
# mESC.6h.dTag.120min.4sU.B                          0.0
# mESC.6h.dTag.120min.4sU.C                          0.0
# mESC.20h.dTag.120min.4sU.A                         0.0
# mESC.20h.dTag.120min.4sU.B                         0.0
# mESC.20h.dTag.120min.4sU.C                         0.0

# %% [markdown]
# It is possible to restrict the samples to be used by defining the columns parameter (samples for bulk experiments, or cells for single cell experiments are jointly called 'columns' in grandPy):

# %%
banp.get_contrasts(contrast = ["Condition", "dTag 0h 4sU"], columns = banp.coldata["Genotype"] == "dTag")

# %% [markdown]
# If you want to perform comparisons involving no4sU samples (which usually are control samples only), you can do this by setting the no4sU parameter to True:

# %%
banp.get_contrasts(contrast = ["has.4sU", "4sU", "no4sU"], columns = banp.coldata["Genotype"] == "wt", no4su = True)
# Out:
#                             4sU vs no4sU
# Name
# mESC.0h.wt.0h.no4sU.A               -1.0
# mESC.0h.wt.0h.no4sU.B               -1.0
# mESC.0h.wt.0h.no4sU.C               -1.0
# mESC.0h.wt.2h.4sU.A                  1.0
# mESC.0h.wt.2h.4sU.B                  1.0
# mESC.0h.wt.2h.4sU.C                  1.0
# mESC.0h.dTag.2h.4sU.A                0.0
# mESC.0h.dTag.2h.4sU.B                0.0
# mESC.1h.dTag.30min.4sU.A             0.0
# mESC.1h.dTag.30min.4sU.B             0.0
# mESC.1h.dTag.30min.4sU.C             0.0
# mESC.2h.dTag.90min.4sU.A             0.0
# mESC.2h.dTag.90min.4sU.B             0.0
# mESC.2h.dTag.90min.4sU.C             0.0
# mESC.4h.dTag.120min.4sU.A            0.0
# mESC.4h.dTag.120min.4sU.B            0.0
# mESC.4h.dTag.120min.4sU.C            0.0
# mESC.6h.dTag.120min.4sU.A            0.0
# mESC.6h.dTag.120min.4sU.B            0.0
# mESC.6h.dTag.120min.4sU.C            0.0
# mESC.20h.dTag.120min.4sU.A           0.0
# mESC.20h.dTag.120min.4sU.B           0.0
# mESC.20h.dTag.120min.4sU.C           0.0

# %% [markdown]
# Sometimes, you want to perform comparisons only among samples from specific groups of samples. This is useful e.g. if you want to compare treatment vs control under different conditions (e.g. cell types), or perform paired pairwise tests (if replicates A, B and C were paired, like in the following example):

# %%
banp.get_contrasts(contrast = ["has.4sU", "4sU", "no4sU"], columns = banp.coldata["Genotype"] == "wt", no4su = True, group = "Replicate")
# Out:
#                             4sU vs no4sU.A  4sU vs no4sU.B  4sU vs no4sU.C
# Name
# mESC.0h.wt.0h.no4sU.A                 -1.0             0.0             0.0
# mESC.0h.wt.0h.no4sU.B                  0.0            -1.0             0.0
# mESC.0h.wt.0h.no4sU.C                  0.0             0.0            -1.0
# mESC.0h.wt.2h.4sU.A                    1.0             0.0             0.0
# mESC.0h.wt.2h.4sU.B                    0.0             1.0             0.0
# mESC.0h.wt.2h.4sU.C                    0.0             0.0             1.0
# mESC.0h.dTag.2h.4sU.A                  0.0             0.0             0.0
# mESC.0h.dTag.2h.4sU.B                  0.0             0.0             0.0
# mESC.1h.dTag.30min.4sU.A               0.0             0.0             0.0
# mESC.1h.dTag.30min.4sU.B               0.0             0.0             0.0
# mESC.1h.dTag.30min.4sU.C               0.0             0.0             0.0
# mESC.2h.dTag.90min.4sU.A               0.0             0.0             0.0
# mESC.2h.dTag.90min.4sU.B               0.0             0.0             0.0
# mESC.2h.dTag.90min.4sU.C               0.0             0.0             0.0
# mESC.4h.dTag.120min.4sU.A              0.0             0.0             0.0
# mESC.4h.dTag.120min.4sU.B              0.0             0.0             0.0
# mESC.4h.dTag.120min.4sU.C              0.0             0.0             0.0
# mESC.6h.dTag.120min.4sU.A              0.0             0.0             0.0
# mESC.6h.dTag.120min.4sU.B              0.0             0.0             0.0
# mESC.6h.dTag.120min.4sU.C              0.0             0.0             0.0
# mESC.20h.dTag.120min.4sU.A             0.0             0.0             0.0
# mESC.20h.dTag.120min.4sU.B             0.0             0.0             0.0
# mESC.20h.dTag.120min.4sU.C             0.0             0.0             0.0

# %% [markdown]
# Finally, if you are not happy with the column names (which end up as the names for analysis tables), you can change this as well:

# %%
banp.get_contrasts(contrast = ["has.4sU", "4sU", "no4sU"], columns = banp.coldata["Genotype"] == "wt", no4su = True, group = "Replicate", name_format = "$GRP")
# Out:
#                               A    B    C
# Name
# mESC.0h.wt.0h.no4sU.A      -1.0  0.0  0.0
# mESC.0h.wt.0h.no4sU.B       0.0 -1.0  0.0
# mESC.0h.wt.0h.no4sU.C       0.0  0.0 -1.0
# mESC.0h.wt.2h.4sU.A         1.0  0.0  0.0
# mESC.0h.wt.2h.4sU.B         0.0  1.0  0.0
# mESC.0h.wt.2h.4sU.C         0.0  0.0  1.0
# mESC.0h.dTag.2h.4sU.A       0.0  0.0  0.0
# mESC.0h.dTag.2h.4sU.B       0.0  0.0  0.0
# mESC.1h.dTag.30min.4sU.A    0.0  0.0  0.0
# mESC.1h.dTag.30min.4sU.B    0.0  0.0  0.0
# mESC.1h.dTag.30min.4sU.C    0.0  0.0  0.0
# mESC.2h.dTag.90min.4sU.A    0.0  0.0  0.0
# mESC.2h.dTag.90min.4sU.B    0.0  0.0  0.0
# mESC.2h.dTag.90min.4sU.C    0.0  0.0  0.0
# mESC.4h.dTag.120min.4sU.A   0.0  0.0  0.0
# mESC.4h.dTag.120min.4sU.B   0.0  0.0  0.0
# mESC.4h.dTag.120min.4sU.C   0.0  0.0  0.0
# mESC.6h.dTag.120min.4sU.A   0.0  0.0  0.0
# mESC.6h.dTag.120min.4sU.B   0.0  0.0  0.0
# mESC.6h.dTag.120min.4sU.C   0.0  0.0  0.0
# mESC.20h.dTag.120min.4sU.A  0.0  0.0  0.0
# mESC.20h.dTag.120min.4sU.B  0.0  0.0  0.0
# mESC.20h.dTag.120min.4sU.C  0.0  0.0  0.0

# %% [markdown]
# # Differential analysis of 4sU treatment and dTag

# %% [markdown]
# Now we can investigate the two unwanted effects mentioned above using differential analysis and lfc (inspired by [[3]](https://academic.oup.com/bioinformatics/article/34/23/4054/5040306?login=false)) and PyDESeq2:

# %%
contrast_1 = banp.get_contrasts(contrast = ["has.4sU", "4sU", "no4sU"], columns = banp.coldata["Genotype"] == "wt", no4su = True, name_format = "4sU effect")
contrast_2 = banp.get_contrasts(contrast=["Genotype","dTag","wt"], columns = banp.coldata["Experimental.time"] == 0, name_format = "dTag effect")

contrasts = pd.concat([contrast_1, contrast_2], axis = 1)

banp = banp.compute_lfc(name_prefix= "QC", contrasts = contrasts, compute_m = False)
print(banp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 6
#       2 contrast_2 = banp.get_contrasts(contrast=["Genotype","dTag","wt"], columns = banp.coldata["Experimental.time"] == 0, name_format = "dTag effect")
#       4 contrasts = pd.concat([contrast_1, contrast_2], axis = 1)
# ----> 6 banp = banp.compute_lfc(name_prefix= "QC", contrasts = contrasts, compute_m = False)
#       7 print(banp)
#
# File ~\PycharmProjects\grandpy\grandpy\grandPy.py:2882, in GrandPy.compute_lfc(self, name_prefix, contrasts, mode_slot, lfc_function, normalization, compute_m, genes, verbose, **kwargs)
#    2833 """
#    2834 Estimate log2 fold changes and optional M values for each contrast.
#    2835
#    (...)   2878     "{prefix}_{contrast}_M".
#    2879 """
#    2880 from .diffexp import _compute_lfc
# -> 2882 new_gp = _compute_lfc(data=self, name_prefix=name_prefix, contrasts=contrasts, mode_slot=mode_slot, lfc_function=lfc_function,
#    2883                       normalization=normalization, compute_m=compute_m, genes=genes, verbose=verbose, **kwargs)
#    2885 return new_gp
#
# File ~\PycharmProjects\grandpy\grandpy\diffexp.py:185, in _compute_lfc(data, name_prefix, contrasts, mode_slot, lfc_function, normalization, compute_m, genes, verbose, **kwargs)
#     183     # append analysis to object
#     184     name = f"{name_prefix}_{contrast}"
# --> 185     new_data = new_data.with_analysis(name, table)
#     187 return new_data
#
# File ~\PycharmProjects\grandpy\grandpy\grandPy.py:671, in GrandPy.with_analysis(self, name, table)
#     635 def with_analysis(self, name: str, table: pd.DataFrame) -> "GrandPy":
#     636     """
#     637     Returns a new GrandPy object with added analyses.
#     638
#    (...)    669     A new GrandPy object with added analyses.
#     670     """
# --> 671     new_analyses = self.__analysis_tool.with_analysis(name, table)
#     673     return self._dev_replace(analyses=new_analyses)
#
# File ~\PycharmProjects\grandpy\grandpy\analysis_tool.py:73, in AnalysisTool.with_analysis(self, name, table)
#      70     raise TypeError(f"'table' has to be a pd.DataFrame, not {type(table)}")
#      72 if not table.index.name == "Symbol":
# ---> 73     raise ValueError(f"Index of 'table' has to be named 'Symbol'. It is currently named: {table.index.name}.")
#      75 new_analyses = self._adata.uns["analyses"].copy()
#      77 new_analyses = {} if new_analyses is None else new_analyses
#
# ValueError: Index of 'table' has to be named 'Symbol'. It is currently named: None.

# %% [markdown]
# As you see, now we have two analyses added to our grandPy object. We can use PlotScatter to directly plot them:

# %%
gp.plot_scatter(banp, x_limit = (-2.0,2.0), y_limit = (-2.0,2.0), remove_outlier = False)

# %% [markdown]
# This works since there are only two analyses overall that are stored in the object (this is also why we used the compute.M = FALSE parameter above; By default, compute_lfc also computes the mean (M) expression value in log10 space to enable generating MA plots):
